# %%
#importing all packages required
from urllib.request import urlopen
import pandas as pd
import json
from elasticsearch import Elasticsearch, RequestsHttpConnection
from newsapi import NewsApiClient
import warnings

# %%
#Elasticsearch connection function
def Elasticsearch_connection(host_link,user_auth):
    warnings.filterwarnings("ignore")
    es = Elasticsearch(hosts=host_link ,verify_certs=False,http_auth= user_auth, connection_class=RequestsHttpConnection,)
    print("ElasticSearch connection has been established and this connection instance is stored in es variable")
    return es

# %%
es = Elasticsearch_connection(['https://tux-es1.cci.drexel.edu:9200/','https://tux-es2.cci.drexel.edu:9200/','https://tux-es3.cci.drexel.edu:9200/'],'ms4976:Phooh3ahkei7')
# Out:
# ElasticSearch connection has been established and this connection instance is stored in es variable

# %% [markdown]
# **Testing and evaluating search engine indices:**

# %% [markdown]
# __Use case 1 : "Crimes in US" on index "ms4976_info624_201904_newsproject1"__

# %%
es.search(index = 'ms4976_info624_201904_newsproject1', body=
{"from":0, "size":10,
 "query": 
 {
   "bool":
   {
     "must":
     [{
        "multi_match": 
        {
          "query": "crimes in US",
          "fields": ["title^2","description"]
        }
     }],
     "should":
     {
       "rank_feature":
       {
         "field": "timestamp",
         "sigmoid":{"pivot": 5,"exponent":0.6}
       }
     } 
   }
  }
})
# Out:
# {'took': 30,
#  'timed_out': False,
#  '_shards': {'total': 1, 'successful': 1, 'skipped': 0, 'failed': 0},
#  'hits': {'total': {'value': 347, 'relation': 'eq'},
#   'max_score': 18.714148,
#   'hits': [{'_index': 'ms4976_info624_201904_newsproject',
#     '_type': '_doc',
#     '_id': '2223',
#     '_score': 18.714148,
#     '_source': {'source': 'Wired',
#      'author': 'Matt Burgess, WIRED UK',
#      'title': 'A British AI Tool to Predict Violent Crime Is Too Flawed to Use',
#      'description': 'A government-funded system known as Most Serious Violence was built to predict first offenses but turned out to be wildly inaccurate.',
#      'url': 'https://www.wired.com/story/a-british-ai-tool-to-predict-violent-crime-is-too-flawed-to-use/',
#      'publishedAt': '2020-08-09T13:00:00Z',
#      'timestamp': 0.00023691392416765148}},
#    {'_index': 'ms4976_info624_201904_newsproject',
#     '_type': '_doc',
#     '_id': '2237',
#     '_score': 12.209831,
#     '_source': {'source': 'Reuters',
#      'author': 'Reuters Editorial',
#      'title': 'and Hong Kong suspend crime treaties | Reuters Video - Reuters',
#      'description': "The U.S. State Department said it notified Hong Kong on Wednesday that Washington has suspended or terminated three bilateral agreements with the semi-autonomous city following China's imposition of a sweeping national security law.",
#      'url': 'https://www.reuters.com/video/watch/idPbze?now=true',
#      'publishedAt': '2020-08-20T13:54:10Z',
#      'timestamp': 0.0002370553982058388}},
#    {'_index': 'ms4976_info624_201904_newsproject',
#     '_type': '_doc',
#     '_id': '2228',
#     '_score': 12.209828,
#     '_source': {'source': 'Gizmodo.com',
#      'author': 'Tom McKay',
#      'title': 'Twitter Trends Are a Crime Against Me, the President, Tweets President',
#      'description': 'Today in squirmy little squids squirting clouds of ink: Twitter trends that make the president look bad are somehow illegal, according to the president. Read more...',
#      'url': 'https://gizmodo.com/twitter-trends-are-a-crime-against-me-the-president-t-1844524663',
#      'publishedAt': '2020-07-28T01:35:00Z',
#      'timestamp': 0.00023675401763405726}},
#    {'_index': 'ms4976_info624_201904_newsproject',
#     '_type': '_doc',
#     '_id': '2231',
#     '_score': 11.668545,
#     '_source': {'source': 'New York Times',
#      'author': 'Alan Feuer',
#      'title': 'The Mayor Blames the Virus for Shootings. Here’s What Crime Data Shows.',
#      'description': 'Mr. de Blasio has pointed to court delays and bail reform to explain the surge in gun violence. But the N.Y.P.D.’s own numbers tell a different story.',
#      'url': 'https://www.nytimes.com/2020/08/04/nyregion/nyc-shootings-coronavirus.html',
#      'publishedAt': '2020-08-04T09:00:21Z',
#      'timestamp': 0.0002368477038145953}},
#    {'_index': 'ms4976_info624_201904_newsproject',
#     '_type': '_doc',
#     '_id': '2236',
#     '_score': 11.173228,
#     '_source': {'source': 'Reuters',
#      'author': 'Reuters Editorial',
#      'title': "Egypt passes law shielding sex crime victims' identities - Reuters Africa",
#      'description': "Egypt's parliament on Tuesday gave its final approval to a law protecting the identity of victims of sexual harassment and assault, aimed at encouraging women who fear social stigma to report such crimes.",
#      'url': 'https://af.reuters.com/article/commoditiesNews/idAFL8N2FJ34U',
#      'publishedAt': '2020-08-18T18:59:00Z',
#      'timestamp': 0.00023703247663750627}},
#    {'_index': 'ms4976_info624_201904_newsproject',
#     '_type': '_doc',
#     '_id': '2224',
#     '_score': 11.173225,
#     '_source': {'source': 'TechCrunch',
#      'author': 'Ingrid Lunden',
#      'title': 'ComplyAdvantage nabs $50M for an AI platform and database to detect and stop financial crime',
#      'description': 'The growth of digital banking has opened up a wealth of opportunities for making the world of finance more accessible and transparent to a greater number of people. But the darker underbelly is that it has also created more avenues for illicit activity to flo…',
#      'url': 'http://techcrunch.com/2020/07/28/complyadvantage-nabs-50m-for-an-ai-platform-and-database-to-detect-and-stop-financial-crime/',
#      'publishedAt': '2020-07-28T10:35:25Z',
#      'timestamp': 0.00023675882788487068}},
#    {'_index': 'ms4976_info624_201904_newsproject',
#     '_type': '_doc',
#     '_id': '2021',
#     '_score': 10.298891,
#     '_source': {'source': 'Gizmodo.com',
#      'author': 'Whitney Kimball',
#      'title': "U.S. Army Esports Team Says It's Unbanning Americans Who Asked About W4r Crimes",
#      'description': 'The U.S. Army says it will restore Americans’ God-given right to shitpost on its esports channel, the premier destination for watching your favorite former sniper shoot up digital Middle Eastern villages. The Verge reports that the Army has decided to unban p…',
#      'url': 'https://gizmodo.com/u-s-army-esports-team-says-its-unbanning-americans-who-1844635290',
#      'publishedAt': '2020-08-06T16:59:00Z',
#      'timestamp': 0.00023687759917106934}},
#    {'_index': 'ms4976_info624_201904_newsproject',
#     '_type': '_doc',
#     '_id': '2233',
#     '_score': 10.298891,
#     '_source': {'source': 'BBC News',
#      'author': 'https://www.facebook.com/bbcnews',
#      'title': "Mexico's war on drugs: Mexican police seize alleged oil theft crime boss The Sledgehammer",
#      'description': 'The man known as The Sledgehammer had released a bizarre, tearful video declaring war on security forces.',
#      'url': 'https://www.bbc.co.uk/news/world-latin-america-53632616',
#      'publishedAt': '2020-08-03T01:36:56Z',
#      'timestamp': 0.00023683093951565402}},
#    {'_index': 'ms4976_info624_201904_newsproject',
#     '_type': '_doc',
#     '_id': '385',
#     '_score': 9.911117,
#     '_source': {'source': 'Google News',
#      'author': None,
#      'title': "Police launch hate crime investigation after man yells obscenities at McKenna's office - CBC News",
#      'description': "Police launch hate crime investigation after man yells obscenities at McKenna's office\xa0\xa0CBC NewsView Full coverage on Google News",
#      'url': 'https://news.google.com/__i/rss/rd/articles/CBMiK2h0dHBzOi8vd3d3LnlvdXR1YmUuY29tL3dhdGNoP3Y9cG03cC0tN2dfOXfSAQA?oc=5',
#      'publishedAt': '2020-08-10T23:01:22Z',
#      'timestamp': 0.00023693209438014584}},
#    {'_index': 'ms4976_info624_201904_newsproject',
#     '_type': '_doc',
#     '_id': '2229',
#     '_score': 9.911117,
#     '_source': {'source': 'New York Times',
#      'author': 'Michael Levenson',
#      'title': 'Man Charged With Murdering 4-Year-Old Whose Killing Prompted U.S. Anti-Crime Operation',
#      'description': 'The Justice Department last month named an operation to combat violent crime in cities after LeGend Taliferro, who was shot and killed while he slept in an apartment in Kansas City, Mo.',
#      'url': 'https://www.nytimes.com/2020/08/13/us/legend-taliferrro-arrest.html',
#      'publishedAt': '2020-08-14T02:17:18Z',
#      'timestamp': 0.00023697229071998864}}]}}

# %% [markdown]
# The information needs for this query ("crimes in US") is to find all relevant news articles from the "ms4976_info624_201904_newsproject1" index which have any details regarding crimes that are happening in united states. We can observe from the query Top 10 results where Doc 1,Doc 5,Doc 8 are not relevant to our query information needs.
#
# Below are relevant and non-relevant document based on the query information needs
#
#     Relevant = Doc 2,Doc 3,Doc 4,Doc 6, Doc 7,Doc 9,Doc 10
#
#     Non-Relevant = Doc 1,Doc 5,Doc 8

# %% [markdown]
# Precision is defined as percentage of retrieved docs that are relevant
#
#     Precision = True positive(TP)/True positive(TP) + False Positive(FP)
#               = 7/(7+3)
#               =7/10
#               =0.7
#
# DCG appears to have high value if the top retrieved documents are relevant
#
# Discounted cumulative gain can be given by below formula:
#
#     DCG = rel1+ (rel2/log(2)) + (rel3/log(3)) + (rel4/log(4)) + (rel5/log(5)) + (rel6/log(6)) + (rel7/log(7)) +(rel8/log(8))   (rel9/log(9)) +(rel10/log(10))
#
# Here relevance value for any document will be 1 if the retrieved document is relevant to the query needs and 0 if the retrieved document is not relevant to the query needs
#
#     DCG = 0+ (1/log(2)) + (1/log(3)) + (1/log(4)) + (0/log(5)) + (1/log(6)) + (1/log(7)) + (0/log(8)) + (1/log(9))+(1/log(10))
#         = 0 + 1/1 + 1/1.58 +1/2 + 0/2.32 + 1/2.58 + 1/2.8 + 0/3 + 1/3.17+ 1/3.32
#         = 1 + 0.63 + 0.5 + 0.39 +0.36 + 0.31 + 0.3
#         =3.49
#
# IDCG can be calculated by re-ordering the retreived results by making all relevant results at top in decreasing order of their scores
#
#     IDCG = 1+(1/log(2)) +(1/log(3)) + (1/log(4)) + (1/log(5)) + (1/log(6)) + (1/log(7)) +(0/log(8)) +(0/log(9)) +(0/log(10))
#         = 1 + 1/1 + 1/1.58 +1/2 + 1/2.32 + 1/2.58 + 1/2.8 + 0/3 + 0/3.17+ 0/3.32
#         = 1 + 1 + 0.63 + 0.5 +0.43 + 0.39 +0.36
#         =4.31
#
# Normalized DCG(nDCG) can be calculated by using DCG and IDCG as shown below
#
#     nDCG = DCG/IDCG
#          =3.49/4.31
#          =0.8

# %% [markdown]
# __Use case 2 : "articles by BBC news" on index "ms4976_info624_201904_newsproject1"__

# %%
es.search(index = 'ms4976_info624_201904_newsproject1', body=
{"from":0, "size":10,
 "query": 
 {
   "bool":
   {
     "must":
     [{
        "multi_match": 
        {
          "query": "articles by BBC news",
          "fields": ["source^3","title","description"]
        }
     }],
     "should":
     {
       "rank_feature":
       {
         "field": "timestamp",
         "sigmoid":{"pivot": 5,"exponent":0.6}
       }
     } 
   }
  }
})
# Out:
# {'took': 8,
#  'timed_out': False,
#  '_shards': {'total': 1, 'successful': 1, 'skipped': 0, 'failed': 0},
#  'hits': {'total': {'value': 947, 'relation': 'eq'},
#   'max_score': 21.565105,
#   'hits': [{'_index': 'ms4976_info624_201904_newsproject',
#     '_type': '_doc',
#     '_id': '206',
#     '_score': 21.565105,
#     '_source': {'source': 'BBC News',
#      'author': 'https://www.facebook.com/bbcnews',
#      'title': 'Musicians hire fishing boat to beat France quarantine - BBC News',
#      'description': '<ol><li>Musicians hire fishing boat to beat France quarantine\xa0\xa0BBC News\r\n</li><li>British tourists rush back from France to avoid quarantine\xa0\xa0CNN\r\n</li><li>Thousands of Britons return from France to avoid quarantine\xa0\xa0ABC News\r\n</li><li>The French quarantine f…',
#      'url': 'https://www.bbc.com/news/uk-scotland-53792546',
#      'publishedAt': '2020-08-15T13:07:04Z',
#      'timestamp': 0.00023699089174106783}},
#    {'_index': 'ms4976_info624_201904_newsproject',
#     '_type': '_doc',
#     '_id': '207',
#     '_score': 21.565105,
#     '_source': {'source': 'BBC News',
#      'author': 'https://www.facebook.com/bbcnews',
#      'title': "More House of Fraser store closures 'anticipated' - BBC News",
#      'description': "<ol><li>More House of Fraser store closures 'anticipated'\xa0\xa0BBC News\r\n</li><li>House of Fraser owner threatens landlords with store closures over rent\xa0\xa0The Guardian\r\n</li><li>Mike Ashley's Frasers Group retail empire see profits slump by a fifth\xa0\xa0Sky News\r\n</l…",
#      'url': 'https://www.bbc.com/news/business-53845264',
#      'publishedAt': '2020-08-20T11:26:15Z',
#      'timestamp': 0.00023705408159902403}},
#    {'_index': 'ms4976_info624_201904_newsproject',
#     '_type': '_doc',
#     '_id': '208',
#     '_score': 21.565105,
#     '_source': {'source': 'BBC News',
#      'author': 'https://www.facebook.com/bbcnews',
#      'title': 'BTec grades pulled on eve of results day - BBC News',
#      'description': 'BTec grades pulled on eve of results day\xa0\xa0BBC NewsView Full coverage on Google News',
#      'url': 'https://www.bbc.com/news/education-53843148',
#      'publishedAt': '2020-08-19T21:45:00Z',
#      'timestamp': 0.00023704677164963832}},
#    {'_index': 'ms4976_info624_201904_newsproject',
#     '_type': '_doc',
#     '_id': '209',
#     '_score': 21.565105,
#     '_source': {'source': 'BBC News',
#      'author': 'BBC News',
#      'title': "Coronavirus: London renting 'feels different' after lockdown - BBC News",
#      'description': "<ol><li>Coronavirus: London renting 'feels different' after lockdown\xa0\xa0BBC News\r\n</li><li>15 commuter towns Londoners are moving to, according to an estate agent\xa0\xa0My London\r\n</li><li>View Full coverage on Google News</li></ol>",
#      'url': 'https://www.bbc.com/news/av/uk-england-london-53861413/coronavirus-london-renting-feels-different-after-lockdown',
#      'publishedAt': '2020-08-22T04:34:45Z',
#      'timestamp': 0.00023707605372694929}},
#    {'_index': 'ms4976_info624_201904_newsproject',
#     '_type': '_doc',
#     '_id': '218',
#     '_score': 21.565105,
#     '_source': {'source': 'BBC News',
#      'author': None,
#      'title': "O'Sullivan dominates Wilson in first session of Crucible final",
#      'description': "Ronnie O'Sullivan opens up a 6-2 lead over Kyren Wilson after a turgid opening session of the World Championship final in Sheffield.",
#      'url': 'https://www.bbc.co.uk/sport/snooker/53792731',
#      'publishedAt': '2020-08-15T15:39:04Z',
#      'timestamp': 0.0002369922446936482}},
#    {'_index': 'ms4976_info624_201904_newsproject',
#     '_type': '_doc',
#     '_id': '220',
#     '_score': 21.565105,
#     '_source': {'source': 'BBC News',
#      'author': None,
#      'title': "O'Sullivan one frame away from sixth Crucible title",
#      'description': "Ronnie O'Sullivan needs one more frame for his sixth World Championship title after opening up a 17-8 lead over Kyren Wilson in the final at the Crucible.",
#      'url': 'https://www.bbc.co.uk/sport/snooker/53795792',
#      'publishedAt': '2020-08-16T15:33:14Z',
#      'timestamp': 0.00023700501021662416}},
#    {'_index': 'ms4976_info624_201904_newsproject',
#     '_type': '_doc',
#     '_id': '221',
#     '_score': 21.565105,
#     '_source': {'source': 'BBC News',
#      'author': None,
#      'title': 'England v Pakistan: Dawid Malan and Chris Jordan return to squad',
#      'description': "Dawid Malan and Chris Jordan are named in England's 14-player squad for the T20 series against Pakistan after recovering from injury.",
#      'url': 'https://www.bbc.co.uk/sport/cricket/53826295',
#      'publishedAt': '2020-08-18T15:20:37Z',
#      'timestamp': 0.00023703053280662244}},
#    {'_index': 'ms4976_info624_201904_newsproject',
#     '_type': '_doc',
#     '_id': '222',
#     '_score': 21.565105,
#     '_source': {'source': 'BBC News',
#      'author': None,
#      'title': "'For her it's a bigger risk than me' - Persoon surprised by Taylor taking rematch",
#      'description': 'Delfine Persoon says she would "box for free" to have the chance to secure a revenge victory in her rematch with Katie Taylor.',
#      'url': 'https://www.bbc.co.uk/sport/boxing/53852488',
#      'publishedAt': '2020-08-20T21:28:58Z',
#      'timestamp': 0.00023705944638237534}},
#    {'_index': 'ms4976_info624_201904_newsproject',
#     '_type': '_doc',
#     '_id': '225',
#     '_score': 21.565105,
#     '_source': {'source': 'BBC News',
#      'author': None,
#      'title': 'Kayaker Kimberley Woods on overcoming bullying and self-harm to reach the Olympics',
#      'description': 'How Kimberley Woods overcame bullying, depression and self-harm to reach the Tokyo Olympics.',
#      'url': 'https://www.bbc.co.uk/sport/olympics/53789670',
#      'publishedAt': '2020-08-16T06:04:24Z',
#      'timestamp': 0.00023699994702895222}},
#    {'_index': 'ms4976_info624_201904_newsproject',
#     '_type': '_doc',
#     '_id': '709',
#     '_score': 21.565105,
#     '_source': {'source': 'BBC News',
#      'author': 'https://www.facebook.com/bbcnews',
#      'title': "Brazilians back reporter whom Bolsonaro 'felt like punching'",
#      'description': 'Brazil\'s President Jair Bolsonaro told a reporter he "felt like covering your face in punches".',
#      'url': 'https://www.bbc.co.uk/news/world-latin-america-53887902',
#      'publishedAt': '2020-08-24T17:02:22Z',
#      'timestamp': 0.0002371083431567503}}]}}

# %% [markdown]
# The information needs for this query ("articles by BBC news") is to find all relevant news articles from the "ms4976_info624_201904_newsproject1" index which are published by BBC news source. We can see from the query results that all the Top 10 retrieved results are relevant to our query information needs.
#
# Below are relevant and non-relevant document based on the query information needs
#
#     relevant = Doc1, Doc 2, Doc 3, Doc 4, Doc 5, Doc 6, Doc 7, Doc 8, Doc 9, Doc 10
#     non-relevant = Null
#
# For this query, we are getting no False Positive as all the retreived results are relevant to the information needs

# %% [markdown]
# Precision is defined as percentage of retrieved docs that are relevant
#
#     Precision = True positive(TP)/True positive(TP) + False Positive(FP)
#               = 10/(10+0)
#               =10/10
#               =1
#
# DCG appears to have high value if the top retrieved documents are relevant
#
# Discounted cumulative gain can be given by below formula:
#
#     DCG = rel1+ (rel2/log(2)) + (rel3/log(3)) + (rel4/log(4)) + (rel5/log(5)) + (rel6/log(6)) + (rel7/log(7)) + (rel8/log(8))   (rel9/log(9)) +(rel10/log(10))
#
# Here relevance value for any document will be 1 if the retrieved document is relevant to the query needs and 0 if the retrieved document is not relevant to the query needs
#
#     DCG = 1+ (1/log(2)) + (1/log(3)) + (1/log(4)) + (1/log(5)) + (1/log(6)) + (1/log(7)) + (1/log(8)) + (1/log(9)) +(1/log(10))
#         = 1 + 1/1 + 1/1.58 +1/2 + 1/2.32 + 1/2.58 + 1/2.8 + 1/3 + 1/3.17+ 1/3.32
#         = 1 + 1 + 0.63 + 0.5 + 0.43 + 0.39 + 0.36 + 0.33 + 0.31 + 0.3
#         =5.25
#
# IDCG can be calculated by re-ordering the retreived results by making all relevant results at top in decreasing order of their scores
#
#     IDCG = 1+ (1/log(2)) + (1/log(3)) + (1/log(4)) + (1/log(5)) + (1/log(6)) + (1/log(7)) + (1/log(8)) + (1/log(9)) +(1/log(10))
#         = 1 + 1/1 + 1/1.58 +1/2 + 1/2.32 + 1/2.58 + 1/2.8 + 1/3 + 1/3.17+ 1/3.32
#         = 1 + 1 + 0.63 + 0.5 + 0.43 + 0.39 +0.36 + 0.33 + 0.31 + 0.3
#         =5.25
#
# Normalized DCG(nDCG) can be calculated by using DCG and IDCG as shown below
#
#     nDCG = DCG/IDCG
#          =5.25/5.25
#          =1

# %% [markdown]
# Use case 3 : "COVID-19" on index "ms4976_info624_201904_newsproject1"

# %%
es.search(index = 'ms4976_info624_201904_newsproject1', body=
{"from":0, "size":10,
 "query": 
 {
   "bool":
   {
     "must":
     [{
        "multi_match": 
        {
          "query": "COVID-19",
          "fields": ["title","description"]
        }
     }],
     "should":
     {
       "rank_feature":
       {
         "field": "timestamp",
         "sigmoid":{"pivot": 5,"exponent":0.6}
       }
     } 
   }
  }
})
# Out:
# {'took': 10,
#  'timed_out': False,
#  '_shards': {'total': 1, 'successful': 1, 'skipped': 0, 'failed': 0},
#  'hits': {'total': {'value': 308, 'relation': 'eq'},
#   'max_score': 8.097325,
#   'hits': [{'_index': 'ms4976_info624_201904_newsproject',
#     '_type': '_doc',
#     '_id': '108',
#     '_score': 8.097325,
#     '_source': {'source': 'TheChronicleHerald.ca',
#      'author': 'Reuters Inc.',
#      'title': 'Chinese COVID-19 vaccine candidate shows promise in animal tests - TheChronicleHerald.ca',
#      'description': "<ol><li>Chinese COVID-19 vaccine candidate shows promise in animal tests\xa0\xa0TheChronicleHerald.ca\r\n</li><li>Russia claims it's in the last phase of COVID-19 vaccine trials\xa0\xa0ABC News\r\n</li><li>COVID-19 Vaccines ‘Making Good Progress’ in Trials But Won’t Be Useab…",
#      'url': 'https://www.thechronicleherald.ca/news/world/chinese-covid-19-vaccine-candidate-shows-promise-in-animal-tests-477118/',
#      'publishedAt': '2020-07-24T09:57:45Z',
#      'timestamp': 0.00023670722283173395}},
#    {'_index': 'ms4976_info624_201904_newsproject',
#     '_type': '_doc',
#     '_id': '1310',
#     '_score': 7.975021,
#     '_source': {'source': 'Google News',
#      'author': None,
#      'title': 'Which Canadians would get the COVID-19 vaccine first? - CBC News',
#      'description': '<ol><li>Which Canadians would get the COVID-19 vaccine first?\xa0\xa0CBC News\r\n</li><li>Large U.S. COVID-19 vaccine trials will exclude pregnant women for now\xa0\xa0National Post\r\n</li><li>Dozens of COVID-19 vaccines are in development. Here are the ones to follow.\xa0\xa0Nat…',
#      'url': 'https://news.google.com/__i/rss/rd/articles/CBMiK2h0dHBzOi8vd3d3LnlvdXR1YmUuY29tL3dhdGNoP3Y9YjNsVVcydnJ1U2fSAQA?oc=5',
#      'publishedAt': '2020-08-01T14:53:19Z',
#      'timestamp': 0.0002368123932357483}},
#    {'_index': 'ms4976_info624_201904_newsproject',
#     '_type': '_doc',
#     '_id': '1314',
#     '_score': 7.975021,
#     '_source': {'source': 'Terrace Standard',
#      'author': 'Associated Press',
#      'title': 'First dog that tested positive for COVID-19 dies in New York - Terrace Standard',
#      'description': '<ol><li>First dog that tested positive for COVID-19 dies in New York\xa0\xa0Terrace Standard\r\n</li><li>Exclusive: Buddy, first dog to test positive for COVID-19 in the U.S., has died\xa0\xa0National Geographic\r\n</li><li>First Dog to Test Positive for COVID-19 in the U.S.…',
#      'url': 'https://www.terracestandard.com/news/first-dog-that-tested-positive-for-covid-19-dies-in-new-york/',
#      'publishedAt': '2020-07-30T22:00:00Z',
#      'timestamp': 0.000236790556254731}},
#    {'_index': 'ms4976_info624_201904_newsproject',
#     '_type': '_doc',
#     '_id': '1315',
#     '_score': 7.975021,
#     '_source': {'source': 'The Dallas Morning News',
#      'author': 'Jesus  Jimenez, Anna Kuchment',
#      'title': 'COVID-19 vaccine trials are underway in Dallas-Fort Worth - The Dallas Morning News',
#      'description': '<ol><li>COVID-19 vaccine trials are underway in Dallas-Fort Worth\xa0\xa0The Dallas Morning News\r\n</li><li>4 phases of COVID-19 vaccine clinical trials explained | USA TODAY\xa0\xa0USA TODAY\r\n</li><li>Dozens of COVID-19 vaccines are in development. Here are the ones to f…',
#      'url': 'https://www.dallasnews.com/news/public-health/2020/07/31/covid-19-vaccine-trials-are-underway-in-dallas-fort-worth/',
#      'publishedAt': '2020-07-31T21:32:34Z',
#      'timestamp': 0.0002368031295160245}},
#    {'_index': 'ms4976_info624_201904_newsproject',
#     '_type': '_doc',
#     '_id': '2992',
#     '_score': 7.895118,
#     '_source': {'source': 'The Chronicle of Higher Education',
#      'author': 'Katherine Mangan',
#      'title': 'The Student-Blaming Has Begun',
#      'description': 'Is it fair to fault college students for Covid-19 outbreaks?',
#      'url': 'https://www.chronicle.com/article/the-student-blaming-has-begun',
#      'publishedAt': '2020-08-22T18:19:42Z',
#      'timestamp': 0.00023708339661004913}},
#    {'_index': 'ms4976_info624_201904_newsproject',
#     '_type': '_doc',
#     '_id': '808',
#     '_score': 7.8563576,
#     '_source': {'source': 'Canewsottawa.ca',
#      'author': 'Miriam Garner',
#      'title': 'Edmonton zone has far more COVID-19 circumstances than any other zone in Alberta - Edmonton - CA News Ottawa',
#      'description': '<ol><li>Edmonton zone has far more COVID-19 circumstances than any other zone in Alberta - Edmonton\xa0\xa0CA News Ottawa\r\n</li><li>Albertans increasing much less contented with COVID-19 reaction, survey says\xa0\xa0The Queens County Citizen\r\n</li><li>COVID-19 preventing…',
#      'url': 'https://www.canewsottawa.ca/edmonton-zone-has-far-more-covid-19-circumstances-than-any-other-zone-in-alberta-edmonton/',
#      'publishedAt': '2020-08-14T02:53:27Z',
#      'timestamp': 0.00023697261249127667}},
#    {'_index': 'ms4976_info624_201904_newsproject',
#     '_type': '_doc',
#     '_id': '2183',
#     '_score': 7.8563576,
#     '_source': {'source': 'Xinhua Net',
#      'author': None,
#      'title': 'Young adults face high risk of COVID-19 infections in Canada - Xinhua | English.news.cn - Xinhua',
#      'description': "<ol><li>Young adults face high risk of COVID-19 infections in Canada - Xinhua | English.news.cn\xa0\xa0Xinhua\r\n</li><li>COVID-19 Daily Update from Dr Tam - Canada's Chief Medical Officer of Health\xa0\xa0Net Newsledger\r\n</li><li>Canadians divided over whether COVID-19 ca…",
#      'url': 'http://www.xinhuanet.com/english/2020-07/27/c_139243499.htm',
#      'publishedAt': '2020-07-27T06:55:30Z',
#      'timestamp': 0.00023674405296028277}},
#    {'_index': 'ms4976_info624_201904_newsproject',
#     '_type': '_doc',
#     '_id': '803',
#     '_score': 7.798343,
#     '_source': {'source': 'country94.ca',
#      'author': 'Brad Perry',
#      'title': 'UPDATE: Only One COVID-19 Case In Atlantic Canada - country94.ca',
#      'description': '<ol><li>UPDATE: Only One COVID-19 Case In Atlantic Canada\xa0\xa0country94.ca\r\n</li><li>No new cases of COVID-19 reported, still 15 active cases in New Brunswick\xa0\xa0CBC.ca\r\n</li><li>No New Cases of COVID-19 Reported in NL\xa0\xa0VOCM\r\n</li><li>View Full coverage on Google …',
#      'url': 'https://www.country94.ca/2020/08/17/no-new-covid-19-cases-in-n-b/',
#      'publishedAt': '2020-08-17T16:52:30Z',
#      'timestamp': 0.00023701853321502503}},
#    {'_index': 'ms4976_info624_201904_newsproject',
#     '_type': '_doc',
#     '_id': '1435',
#     '_score': 7.798343,
#     '_source': {'source': 'STAT',
#      'author': None,
#      'title': 'First Covid-19 reinfection documented in Hong Kong, researchers say - STAT',
#      'description': '<ol><li>First Covid-19 reinfection documented in Hong Kong, researchers say\xa0\xa0STAT\r\n</li><li>Covid-19 News: Live Updates\xa0\xa0The New York Times\r\n</li><li>COVID-19 researchers record first case of reinfection\xa0\xa0New York Post \r\n</li><li>Hong Kong man was reinfected …',
#      'url': 'https://www.statnews.com/2020/08/24/first-covid-19-reinfection-documented-in-hong-kong-researchers-say/',
#      'publishedAt': '2020-08-24T14:04:40Z',
#      'timestamp': 0.0002371067614483718}},
#    {'_index': 'ms4976_info624_201904_newsproject',
#     '_type': '_doc',
#     '_id': '8',
#     '_score': 7.79834,
#     '_source': {'source': 'Google News',
#      'author': None,
#      'title': 'The latest on COVID-19 symptoms - ABC News',
#      'description': '<ol><li>The latest on COVID-19 symptoms\xa0\xa0ABC News\r\n</li><li>Is It COVID-19, Allergies, Flu or a Cold?\xa0\xa0U.S. News & World Report\r\n</li><li>Briefing: Can you get coronavirus twice? Your COVID-19 questions answered\xa0\xa0Waterloo Cedar Falls Courier\r\n</li><li>Why you…',
#      'url': 'https://news.google.com/__i/rss/rd/articles/CBMiK2h0dHBzOi8vd3d3LnlvdXR1YmUuY29tL3dhdGNoP3Y9RjFJdXJTZEpodWfSAQA?oc=5',
#      'publishedAt': '2020-08-10T20:20:52Z',
#      'timestamp': 0.00023693066576903303}}]}}

# %% [markdown]
# The information needs for this query "COVID-19" is to find all relevant news articles from the "ms4976_info624_201904_newsproject1" index which are related to covid -19 virus topics. We can see from the query results that all the Top 10 retrieved results are relevant to our query information needs.
#
# Below are relevant and non-relevant document based on the query information needs
#
#     relevant = Doc1, Doc 2, Doc 3, Doc 4, Doc 5, Doc 6, Doc 7, Doc 8, Doc 9, Doc 10
#     non-relevant = Null
#
# For this query, we are getting no False Positive as all the retreived results are relevant to the information needs.

# %% [markdown]
# Precision is defined as percentage of retrieved docs that are relevant
#
# Precision = True positive(TP)/True positive(TP) + False Positive(FP)
#           = 10/(10+0)
#           =10/10
#           =1
#
# DCG appears to have high value if the top retrieved documents are relevant
#
# Discounted cumulative gain can be given by below formula:
#
#     DCG = rel1+ (rel2/log(2)) + (rel3/log(3)) + (rel4/log(4)) + (rel5/log(5)) + (rel6/log(6)) + (rel7/log(7)) + (rel8/log(8))   (rel9/log(9)) +(rel10/log(10))
#
# Here relevance value for any document will be 1 if the retrieved document is relevant to the query needs and 0 if the retrieved document is not relevant to the query needs
#
#     DCG = 1+ (1/log(2)) + (1/log(3)) + (1/log(4)) + (1/log(5)) + (1/log(6)) + (1/log(7)) + (1/log(8)) + (1/log(9)) +(1/log(10))
#         = 1 + 1/1 + 1/1.58 +1/2 + 1/2.32 + 1/2.58 + 1/2.8 + 1/3 + 1/3.17+ 1/3.32
#         = 1 + 1 + 0.63 + 0.5 + 0.43 + 0.39 + 0.36 + 0.33 + 0.31 + 0.3
#         =5.25
#
# IDCG can be calculated by re-ordering the retreived results by making all relevant results at top in decreasing order of their scores
#
#     IDCG = 1+ (1/log(2)) + (1/log(3)) + (1/log(4)) + (1/log(5)) + (1/log(6)) + (1/log(7)) + (1/log(8)) + (1/log(9)) +(1/log(10))
#         = 1 + 1/1 + 1/1.58 +1/2 + 1/2.32 + 1/2.58 + 1/2.8 + 1/3 + 1/3.17+ 1/3.32
#         = 1 + 1 + 0.63 + 0.5 + 0.43 + 0.39 +0.36 + 0.33 + 0.31 + 0.3
#         =5.25
#
# Normalized DCG(nDCG) can be calculated by using DCG and IDCG as shown below
#
#     nDCG = DCG/IDCG
#          =5.25/5.25
#          =1

# %% [markdown]
# Use case 4 : "Annie Karni articles on Trump" on index "ms4976_info624_201904_newsproject1"

# %%
es.search(index = 'ms4976_info624_201904_newsproject1', body=
{"from":0, "size":10,
 "query": 
 {
   "bool":
   {
     "must":
     [{
        "multi_match": 
        {
          "query": "Annie Karni articles on Donald Trump",
          "fields": ["author^5","title","description"]
        }
     }],
     "should":
     {
       "rank_feature":
       {
         "field": "timestamp",
         "sigmoid":{"pivot": 5,"exponent":0.6}
       }
     } 
   }
  }
})
# Out:
# {'took': 207,
#  'timed_out': False,
#  '_shards': {'total': 1, 'successful': 1, 'skipped': 0, 'failed': 0},
#  'hits': {'total': {'value': 395, 'relation': 'eq'},
#   'max_score': 12.603967,
#   'hits': [{'_index': 'ms4976_info624_201904_newsproject1',
#     '_type': '_doc',
#     '_id': '863',
#     '_score': 12.603967,
#     '_source': {'source': 'Pypi.org',
#      'author': 'lucasyangpersonal@gmail.com',
#      'title': 'nw-kaya added to PyPI',
#      'description': 'Simplified python article discovery & extraction.',
#      'url': 'https://pypi.org/project/nw-kaya/',
#      'publishedAt': '2020-08-21T15:08:02Z',
#      'timestamp': 0.0002370688731388191}},
#    {'_index': 'ms4976_info624_201904_newsproject1',
#     '_type': '_doc',
#     '_id': '3143',
#     '_score': 11.348137,
#     '_source': {'source': 'New York Times',
#      'author': 'Ginia Bellafante',
#      'title': 'Why the Big City President Made Cities the Enemy',
#      'description': 'Donald Trump — a lifelong New Yorker — declares war on urban America.',
#      'url': 'https://www.nytimes.com/2020/07/24/nyregion/trump-cities.html',
#      'publishedAt': '2020-07-24T09:00:11Z',
#      'timestamp': 0.00023670671043061415}},
#    {'_index': 'ms4976_info624_201904_newsproject1',
#     '_type': '_doc',
#     '_id': '3014',
#     '_score': 10.854961,
#     '_source': {'source': 'BBC News',
#      'author': 'https://www.facebook.com/bbcnews',
#      'title': "USPS: Pelosi to recall the House to 'save' the post office",
#      'description': 'Speaker Nancy Pelosi accuses President Donald Trump of a "campaign to sabotage the election".',
#      'url': 'https://www.bbc.co.uk/news/world-us-canada-53796435',
#      'publishedAt': '2020-08-17T00:14:48Z',
#      'timestamp': 0.0002370096526835156}},
#    {'_index': 'ms4976_info624_201904_newsproject1',
#     '_type': '_doc',
#     '_id': '147',
#     '_score': 10.002537,
#     '_source': {'source': 'New York Times',
#      'author': 'Annie Karni',
#      'title': 'Trump refrains from disavowing QAnon conspiracy.',
#      'description': '',
#      'url': 'https://www.nytimes.com/2020/08/15/us/elections/trump-refrains-from-disavowing-qanon-conspiracy.html',
#      'publishedAt': '2020-08-15T15:05:52Z',
#      'timestamp': 0.00023699194918032143}},
#    {'_index': 'ms4976_info624_201904_newsproject1',
#     '_type': '_doc',
#     '_id': '1256',
#     '_score': 10.002537,
#     '_source': {'source': 'New York Times',
#      'author': 'Annie Karni, Maggie Haberman and Michael M. Grynbaum',
#      'title': 'RNC Guide: What to Watch for Tonight',
#      'description': 'With a program heavy on all things Trump and overseen by a president highly attuned to how events play on television, the convention offers a test of whether he can appeal beyond his base.',
#      'url': 'https://www.nytimes.com/2020/08/24/us/politics/republican-national-convention-guide.html',
#      'publishedAt': '2020-08-24T19:30:07Z',
#      'timestamp': 0.00023710965828006446}},
#    {'_index': 'ms4976_info624_201904_newsproject1',
#     '_type': '_doc',
#     '_id': '2301',
#     '_score': 10.002537,
#     '_source': {'source': 'New York Times',
#      'author': 'Annie Karni and Astead W. Herndon',
#      'title': 'Kamala Harris Changes the Race While Trump Tells on Himself',
#      'description': 'There were surprises this week that weren’t entirely shocking: Ms. Harris joined Joe Biden’s ticket and President Trump resurrected birtherism. Here’s what to make of the last week in politics.',
#      'url': 'https://www.nytimes.com/2020/08/15/us/politics/trump-biden-kamala.html',
#      'publishedAt': '2020-08-15T09:00:06Z',
#      'timestamp': 0.00023698869348982485}},
#    {'_index': 'ms4976_info624_201904_newsproject1',
#     '_type': '_doc',
#     '_id': '3006',
#     '_score': 10.002537,
#     '_source': {'source': 'New York Times',
#      'author': 'Michael M. Grynbaum and Annie Karni',
#      'title': 'Republicans Rush to Finalize Convention (‘Apprentice’ Producers Are Helping)',
#      'description': 'The party is promising a more traditional in-person spectacle with President Trump speaking every night. Coming into this weekend, producers at the major TV networks had only a foggy idea of what to expect.',
#      'url': 'https://www.nytimes.com/2020/08/22/us/politics/republican-convention-preview.html',
#      'publishedAt': '2020-08-23T01:37:09Z',
#      'timestamp': 0.0002370872903541694}},
#    {'_index': 'ms4976_info624_201904_newsproject1',
#     '_type': '_doc',
#     '_id': '3133',
#     '_score': 10.002537,
#     '_source': {'source': 'New York Times',
#      'author': 'Annie Karni',
#      'title': 'President Trump’s younger brother died Saturday night.',
#      'description': '',
#      'url': 'https://www.nytimes.com/2020/08/16/us/elections/president-trumps-younger-brother-died-saturday-night.html',
#      'publishedAt': '2020-08-16T13:19:21Z',
#      'timestamp': 0.00023700381852056297}},
#    {'_index': 'ms4976_info624_201904_newsproject1',
#     '_type': '_doc',
#     '_id': '3245',
#     '_score': 10.002537,
#     '_source': {'source': 'New York Times',
#      'author': 'Annie Karni',
#      'title': 'Republican Delegates Flock to Charlotte Convention to Renominate President Trump',
#      'description': 'It’s not the convention people will see on television next week. But Republicans are staging a truncated gathering in Charlotte to renominate President Trump.',
#      'url': 'https://www.nytimes.com/2020/08/22/us/politics/Republican-delegates-charlotte-trump.html',
#      'publishedAt': '2020-08-22T19:57:19Z',
#      'timestamp': 0.00023708426549637186}},
#    {'_index': 'ms4976_info624_201904_newsproject1',
#     '_type': '_doc',
#     '_id': '182',
#     '_score': 10.002534,
#     '_source': {'source': 'New York Times',
#      'author': 'Astead W. Herndon and Annie Karni',
#      'title': 'Trump’s Axios Interview, Kanye West’s Campaign: The Latest in the 2020 Race',
#      'description': 'President Trump wants to brand Joe Biden as a doddering gaffe machine. But the incumbent’s own rhetoric causes so much controversy it is overwhelming the strategy.',
#      'url': 'https://www.nytimes.com/2020/08/08/us/politics/trump-biden-polls-interview.html',
#      'publishedAt': '2020-08-08T13:03:26Z',
#      'timestamp': 0.00023690113728226637}}]}}

# %% [markdown]
# The information needs for this query("Annie Karni articles on Donald Trump") is to find all relevant news articles from the "ms4976_info624_201904_newsproject1" index which are Published by Annie Karni Author on any Donald Trump topics.We can observe from the query Top 10 results where Doc 1 is not relevant to our query information needs.
#
# Based on the above query information needs we can categorized these results into relevant and non-relevant document
#
#     relevant = Doc 2,Doc 3,Doc 4,Doc 5,Doc 6, Doc 7,Doc 8,Doc 9,Doc 10
#     non-relevant = Doc 1
#
# For this query, we are getting only one False Positive document among top 10 retreived results and remaining all are relevant to the information needs.

# %% [markdown]
# Precision is defined as percentage of retrieved docs that are relevant
#
#     Precision = True positive(TP)/True positive(TP) + False Positive(FP)
#               = 9/(9+1)
#               =9/10
#               =0.9
#
# DCG appears to have high value if the top retrieved documents are relevant
#
# Discounted cumulative gain can be given by below formula:
#
#     DCG = rel1+ (rel2/log(2)) + (rel3/log(3)) + (rel4/log(4)) + (rel5/log(5)) + (rel6/log(6)) + (rel7/log(7)) + (rel8/log(8))   (rel9/log(9)) +(rel10/log(10))
#
# Here relevance value for any document will be 1 if the retrieved document is relevant to the query needs and 0 if the retrieved document is not relevant to the query needs
#
#     DCG =  0+ (1/log(2)) + (1/log(3)) + (1/log(4)) + (1/log(5)) + (1/log(6)) + (1/log(7)) + (1/log(8)) + (1/log(9)) +(1/log(10))
#         =  0 + 1 + 0.63 + 0.5 + 0.43 + 0.39 + 0.36 + 0.33 + 0.31 + 0.3
#         = 4.25
#
# IDCG can be calculated by re-ordering the retreived results by making all relevant results at top in decreasing order of their scores
#
#     IDCG = 1+ (1/log(2)) + (1/log(3)) + (1/log(4)) + (1/log(5)) + (1/log(6)) + (1/log(7)) + (1/log(8)) + (1/log(9)) +(0/log(10))
#         = 1 + 1/1 + 1/1.58 +1/2 + 1/2.32 + 1/2.58 + 1/2.8 + 1/3 + 1/3.17+ 0/3.32
#         = 1 + 1 + 0.63 + 0.5 + 0.43 + 0.39 +0.36 + 0.33 + 0.31 + 0
#         =4.95
#
# Normalized DCG(nDCG) can be calculated by using DCG and IDCG as shown below
#
#     nDCG = DCG/IDCG
#          =4.25/4.95
#          =0.85

# %% [markdown]
# **Evaluation on  "ms4976_info624_201904_newsproject2" index which has different similarities configuration**

# %% [markdown]
# Use case 1 : "US Elections" on index "ms4976_info624_201904_newsproject2"

# %%
es.search(index = 'ms4976_info624_201904_newsproject2', body=
{"from":0, "size":10,
 "query": 
 {
   "bool":
   {
     "must":
     [{
        "multi_match": 
        {
          "query": "crimes in US",
          "fields": ["title^2","description"]
        }
     }],
     "should":
     {
       "rank_feature":
       {
         "field": "timestamp",
         "sigmoid":{"pivot": 5,"exponent":0.6}
       }
     } 
   }
  }
})

# %% [markdown]
# The information needs for this query ("crimes in US") is to find all relevant news articles from the "ms4976_info624_201904_newsproject2" index which have any details regarding crimes in united states.We can observe from the query Top 10 results where Doc 1,Doc 5,Doc 8 are not relevant to our query information needs.
#
# Below are relevant and non-relevant document based on the query information needs
#
#     relevant = Doc 2,Doc 3,Doc 4,Doc 6, Doc 7,Doc 9,Doc 10
#     non-relevant = Doc 1,Doc 5,Doc 8

# %% [markdown]
# Precision is defined as percentage of retrieved docs that are relevant
#
#     Precision = True positive(TP)/True positive(TP) + False Positive(FP)
#               = 7/(7+3)
#               =7/10
#               =0.7
#
# Discounted cumulative gain can be given by below formula
#
#     DCG = rel1+ (rel2/log(2)) + (rel3/log(3)) + (rel4/log(4)) + (rel5/log(5)) + (rel6/log(6)) + (rel7/log(7)) + (rel8/log(8))   (rel9/log(9)) +(rel10/log(10))
#
# Here relevance value for any document will be 1 if the retrieved document is relevant to the query needs and 0 if the retrieved document is not relevant to the query needs
#
#     DCG = 0+ (1/log(2)) + (1/log(3)) + (1/log(4)) + (0/log(5)) + (1/log(6)) + (1/log(7)) + (0/log(8)) + (1/log(9)) +(1/log(10))
#         = 0 + 1/1 + 1/1.58 +1/2 + 0/2.32 + 1/2.58 + 1/2.8 + 0/3 + 1/3.17+ 1/3.32
#         = 1 + 0.63 + 0.5 + 0.39 +0.36 + 0.31 + 0.3
#         =3.49
#
# IDCG can be calculated by re-ordering the retreived results by making all relevant results at top in decreasing order of their scores
#
#     IDCG = 1+ (1/log(2)) + (1/log(3)) + (1/log(4)) + (1/log(5)) + (1/log(6)) + (1/log(7)) + (0/log(8)) + (0/log(9)) +(0/log(10))
#         = 1 + 1/1 + 1/1.58 +1/2 + 1/2.32 + 1/2.58 + 1/2.8 + 0/3 + 0/3.17+ 0/3.32
#         = 1 + 1 + 0.63 + 0.5 +0.43 + 0.39 +0.36
#         =4.31
#
# Normalized DCG(nDCG) can be calculated by using DCG and IDCG as shown below
#
#     nDCG = DCG/IDCG
#          =3.49/4.31
#          =0.8

# %% [markdown]
# Use case 2 : "articles by BBC news" on index "ms4976_info624_201904_newsproject2"

# %%
es.search(index = 'ms4976_info624_201904_newsproject2', body=
{"from":0, "size":10,
 "query": 
 {
   "bool":
   {
     "must":
     [{
        "multi_match": 
        {
          "query": "articles by BBC news",
          "fields": ["source^3","title","description"]
        }
     }],
     "should":
     {
       "rank_feature":
       {
         "field": "timestamp",
         "sigmoid":{"pivot": 5,"exponent":0.6}
       }
     } 
   }
  }
})

# %% [markdown]
# The information needs for this query("articles by BBC news") is to find all relevant news articles from the "ms4976_info624_201904_newsproject2" index which are published by BBC news source.We can see from the query results that all the Top 10 retrieved results are relevant to our query information needs.
#
# Below are relevant and non-relevant document based on the query information needs
#
#     relevant = Doc1, Doc 2, Doc 3, Doc 4, Doc 5, Doc 6, Doc 7, Doc 8, Doc 9, Doc 10
#     non-relevant = Null
#
# For this query, we are getting no False Positive as all the retreived results are relevant to the information needs

# %% [markdown]
# Precision is defined as percentage of retrieved docs that are relevant
#
#     Precision = True positive(TP)/True positive(TP) + False Positive(FP)
#               = 10/(10+0)
#               =10/10
#               =1
#
# DCG appears to have high value if the top retrieved documents are relevant
#
# Discounted cumulative gain can be given by below formula:
#
#     DCG = rel1+ (rel2/log(2)) + (rel3/log(3)) + (rel4/log(4)) + (rel5/log(5)) + (rel6/log(6)) + (rel7/log(7)) + (rel8/log(8))   (rel9/log(9)) +(rel10/log(10))
#
# Here relevance value for any document will be 1 if the retrieved document is relevant to the query needs and 0 if the retrieved document is not relevant to the query needs
#
#     DCG = 1+ (1/log(2)) + (1/log(3)) + (1/log(4)) + (1/log(5)) + (1/log(6)) + (1/log(7)) + (1/log(8)) + (1/log(9)) +(1/log(10))
#         = 1 + 1/1 + 1/1.58 +1/2 + 1/2.32 + 1/2.58 + 1/2.8 + 1/3 + 1/3.17+ 1/3.32
#         = 1 + 1 + 0.63 + 0.5 + 0.43 + 0.39 + 0.36 + 0.33 + 0.31 + 0.3
#         =5.25
#
# IDCG can be calculated by re-ordering the retreived results by making all relevant results at top in decreasing order of their scores
#
#     IDCG = 1+ (1/log(2)) + (1/log(3)) + (1/log(4)) + (1/log(5)) + (1/log(6)) + (1/log(7)) + (1/log(8)) + (1/log(9)) +(1/log(10))
#         = 1 + 1/1 + 1/1.58 +1/2 + 1/2.32 + 1/2.58 + 1/2.8 + 1/3 + 1/3.17+ 1/3.32
#         = 1 + 1 + 0.63 + 0.5 + 0.43 + 0.39 +0.36 + 0.33 + 0.31 + 0.3
#         =5.25
#
# Normalized DCG(nDCG) can be calculated by using DCG and IDCG as shown below
#
#     nDCG = DCG/IDCG
#          =5.25/5.25
#          =1

# %% [markdown]
# Use case 3 : "COVID-19" on index "ms4976_info624_201904_newsproject2"

# %%
es.search(index = 'ms4976_info624_201904_newsproject2', body=
{"from":0, "size":10,
 "query": 
 {
   "bool":
   {
     "must":
     [{
        "multi_match": 
        {
          "query": "COVID-19",
          "fields": ["title","description"]
        }
     }],
     "should":
     {
       "rank_feature":
       {
         "field": "timestamp",
         "sigmoid":{"pivot": 5,"exponent":0.6}
       }
     } 
   }
  }
})

# %% [markdown]
# The information needs for this query ("COVID-19") is to find all relevant news articles from the "ms4976_info624_201904_newsproject2" index which are related to covid -19 virus.We can see from the query results that all the Top 10 retrieved results are relevant to our query information needs.
#
# Below are relevant and non-relevant document based on the query information needs
#
#     relevant = Doc1, Doc 2, Doc 3, Doc 4, Doc 5, Doc 6, Doc 7, Doc 8, Doc 9, Doc 10
#     non-relevant = Null
#
# For this query, we are getting no False Positive as all the retreived results are relevant to the information needs.

# %% [markdown]
# Precision is defined as percentage of retrieved docs that are relevant
#
#     Precision = True positive(TP)/True positive(TP) + False Positive(FP)
#               = 10/(10+0)
#               =10/10
#               =1
#
# DCG appears to have high value if the top retrieved documents are relevant
#
# Discounted cumulative gain can be given by below formula:
#
#     DCG = rel1+ (rel2/log(2)) + (rel3/log(3)) + (rel4/log(4)) + (rel5/log(5)) + (rel6/log(6)) + (rel7/log(7)) + (rel8/log(8))   (rel9/log(9)) +(rel10/log(10))
#
# Here relevance value for any document will be 1 if the retrieved document is relevant to the query needs and 0 if the retrieved document is not relevant to the query needs
#
#     DCG = 1+ (1/log(2)) + (1/log(3)) + (1/log(4)) + (1/log(5)) + (1/log(6)) + (1/log(7)) + (1/log(8)) + (1/log(9)) +(1/log(10))
#         = 1 + 1/1 + 1/1.58 +1/2 + 1/2.32 + 1/2.58 + 1/2.8 + 1/3 + 1/3.17+ 1/3.32
#         = 1 + 1 + 0.63 + 0.5 + 0.43 + 0.39 + 0.36 + 0.33 + 0.31 + 0.3
#         =5.25
#
# IDCG can be calculated by re-ordering the retreived results by making all relevant results at top in decreasing order of their scores
#
#     IDCG = 1+ (1/log(2)) + (1/log(3)) + (1/log(4)) + (1/log(5)) + (1/log(6)) + (1/log(7)) + (1/log(8)) + (1/log(9)) +(1/log(10))
#         = 1 + 1/1 + 1/1.58 +1/2 + 1/2.32 + 1/2.58 + 1/2.8 + 1/3 + 1/3.17+ 1/3.32
#         = 1 + 1 + 0.63 + 0.5 + 0.43 + 0.39 +0.36 + 0.33 + 0.31 + 0.3
#         =5.25
#
# Normalized DCG(nDCG) can be calculated by using DCG and IDCG as shown below
#
#     nDCG = DCG/IDCG
#          =5.25/5.25
#          =1

# %% [markdown]
# Use case 4 : "Annie Karni articles on Trump" on index "ms4976_info624_201904_newsproject2"

# %%
es.search(index = 'ms4976_info624_201904_newsproject2', body=
{"from":0, "size":10,
 "query": 
 {
   "bool":
   {
     "must":
     [{
        "multi_match": 
        {
          "query": "Annie Karni articles on Donald Trump",
          "fields": ["author^5","title","description"]
        }
     }],
     "should":
     {
       "rank_feature":
       {
         "field": "timestamp",
         "sigmoid":{"pivot": 5,"exponent":0.6}
       }
     } 
   }
  }
})

# %% [markdown]
# The information needs for this query ("Annie Karni articles on Donald Trump") is to find all relevant news articles from the "ms4976_info624_201904_newsproject2" index which are Published by Annie Karni Author on any Donald Trump topics.We can observe from the query Top 10 results where Doc 1,Doc 2,Doc 3 are not relevant to our query information needs.
#
# Based on the above query information needs we can categorized these results into relevant and non-relevant document
#
#     relevant = Doc 4,Doc 5,Doc 6, Doc 7,Doc 8,Doc 9,Doc 10
#     non-relevant = Doc 1,Doc 2,Doc 3
#
# For this query, we are getting three False Positive document among top 10 retreived results and remaining all are relevant to the information needs.

# %% [markdown]
# Precision is defined as percentage of retrieved docs that are relevant
#
#     Precision = True positive(TP)/True positive(TP) + False Positive(FP)
#               = 7/(7+3)
#               =7/10
#               =0.7
#
# DCG appears to have high value if the top retrieved documents are relevant
#
# Discounted cumulative gain can be given by below formula:
#
#     DCG = rel1+ (rel2/log(2)) + (rel3/log(3)) + (rel4/log(4)) + (rel5/log(5)) + (rel6/log(6)) + (rel7/log(7)) + (rel8/log(8))   (rel9/log(9)) +(rel10/log(10))
#
# Here relevance value for any document will be 1 if the retrieved document is relevant to the query needs and 0 if the retrieved document is not relevant to the query needs
#
#     DCG =  0+ (0/log(2)) + (0/log(3)) + (1/log(4)) + (1/log(5)) + (1/log(6)) + (1/log(7)) + (1/log(8)) + (1/log(9)) +(1/log(10))
#         =  0 + 0 + 0 + 0.5 + 0.43 + 0.39 + 0.36 + 0.33 + 0.31 + 0.3
#         = 2.62
#
# IDCG can be calculated by re-ordering the retreived results by making all relevant results at top in decreasing order of their scores
#
#     IDCG = 1+ (1/log(2)) + (1/log(3)) + (1/log(4)) + (1/log(5)) + (1/log(6)) + (1/log(7)) + (0/log(8)) + (0/log(9)) +(0/log(10))
#         = 1 + 1/1 + 1/1.58 +1/2 + 1/2.32 + 1/2.58 + 1/2.8 + 0/3 + 0/3.17+ 0/3.32
#         = 1 + 1 + 0.63 + 0.5 + 0.43 + 0.39 +0.36 + 0 + 0 + 0
#         =4.31
#
# Normalized DCG(nDCG) can be calculated by using DCG and IDCG as shown below
#
#     nDCG = DCG/IDCG
#          =2.62/4.31
#          =0.61

# %% [markdown]
# **Evaluation on  "ms4976_info624_201904_newsproject3" index which has different similarities configuration**

# %% [markdown]
# Use case 1 : "US Elections" on index "ms4976_info624_201904_newsproject3"

# %%
es.search(index = 'ms4976_info624_201904_newsproject3', body=
{"from":0, "size":10,
 "query": 
 {
   "bool":
   {
     "must":
     [{
        "multi_match": 
        {
          "query": "crimes in US",
          "fields": ["title^2","description"]
        }
     }],
     "should":
     {
       "rank_feature":
       {
         "field": "timestamp",
         "sigmoid":{"pivot": 5,"exponent":0.6}
       }
     } 
   }
  }
})

# %% [markdown]
# The information needs for this query ("crimes in US") is to find all relevant news articles from the "ms4976_info624_201904_newsproject3" index which have any details regarding crimes in united states.We can observe from the query Top 10 results where Doc 1,Doc 5,Doc 8 are not relevant to our query information needs.
#
# Below are relevant and non-relevant document based on the query information needs
#
#     relevant = Doc 2,Doc 3,Doc 4,Doc 6, Doc 7,Doc 9,Doc 10
#     non-relevant = Doc 1,Doc 5,Doc 8

# %% [markdown]
# Precision is defined as percentage of retrieved docs that are relevant
#
#     Precision = True positive(TP)/True positive(TP) + False Positive(FP)
#               = 7/(7+3)
#               =7/10
#               =0.7
#
# DCG appears to have high value if the top retrieved documents are relevant
#
# Discounted cumulative gain can be given by below formula:
#
#     DCG = rel1+ (rel2/log(2)) + (rel3/log(3)) + (rel4/log(4)) + (rel5/log(5)) + (rel6/log(6)) + (rel7/log(7)) + (rel8/log(8))   (rel9/log(9)) +(rel10/log(10))
#
# Here relevance value for any document will be 1 if the retrieved document is relevant to the query needs and 0 if the retrieved document is not relevant to the query needs
#
#     DCG = 0+ (1/log(2)) + (1/log(3)) + (1/log(4)) + (0/log(5)) + (1/log(6)) + (1/log(7)) + (0/log(8)) + (1/log(9)) +(1/log(10))
#         = 0 + 1/1 + 1/1.58 +1/2 + 0/2.32 + 1/2.58 + 1/2.8 + 0/3 + 1/3.17+ 1/3.32
#         = 1 + 0.63 + 0.5 + 0.39 +0.36 + 0.31 + 0.3
#         =3.49
#
# IDCG can be calculated by re-ordering the retreived results by making all relevant results at top in decreasing order of their scores
#
#     IDCG = 1+ (1/log(2)) + (1/log(3)) + (1/log(4)) + (1/log(5)) + (1/log(6)) + (1/log(7)) + (0/log(8)) + (0/log(9)) +(0/log(10))
#         = 1 + 1/1 + 1/1.58 +1/2 + 1/2.32 + 1/2.58 + 1/2.8 + 0/3 + 0/3.17+ 0/3.32
#         = 1 + 1 + 0.63 + 0.5 +0.43 + 0.39 +0.36
#         =4.31
#
# Normalized DCG(nDCG) can be calculated by using DCG and IDCG as shown below
#
#     nDCG = DCG/IDCG
#          =3.49/4.31
#          =0.8

# %% [markdown]
# Use case 2 : "articles by BBC news" on index "ms4976_info624_201904_newsproject3"

# %%
es.search(index = 'ms4976_info624_201904_newsproject3', body=
{"from":0, "size":10,
 "query": 
 {
   "bool":
   {
     "must":
     [{
        "multi_match": 
        {
          "query": "articles by BBC news",
          "fields": ["source^3","title","description"]
        }
     }],
     "should":
     {
       "rank_feature":
       {
         "field": "timestamp",
         "sigmoid":{"pivot": 5,"exponent":0.6}
       }
     } 
   }
  }
})

# %% [markdown]
# The information needs for this query("articles by BBC news") is to find all relevant news articles from the "ms4976_info624_201904_newsproject3" index which are published by BBC news source. We can see from the query results that all the Top 10 retrieved results are relevant to our query information needs.
#
# Below are relevant and non-relevant document based on the query information needs
#
#     relevant = Doc1, Doc 2, Doc 3, Doc 4, Doc 5, Doc 6, Doc 7, Doc 8, Doc 9, Doc 10
#     non-relevant = Null
#
# For this query, we are getting no False Positive as all the retreived results are relevant to the information needs

# %% [markdown]
# Precision is defined as percentage of retrieved docs that are relevant
#
#     Precision = True positive(TP)/True positive(TP) + False Positive(FP)
#               = 10/(10+0)
#               =10/10
#               =1
#
# DCG appears to have high value if the top retrieved documents are relevant
#
# Discounted cumulative gain can be given by below formula:
#
#     DCG = rel1+ (rel2/log(2)) + (rel3/log(3)) + (rel4/log(4)) + (rel5/log(5)) + (rel6/log(6)) + (rel7/log(7)) + (rel8/log(8))   (rel9/log(9)) +(rel10/log(10))
#
# Here relevance value for any document will be 1 if the retrieved document is relevant to the query needs and 0 if the retrieved document is not relevant to the query needs
#
#     DCG = 1+ (1/log(2)) + (1/log(3)) + (1/log(4)) + (1/log(5)) + (1/log(6)) + (1/log(7)) + (1/log(8)) + (1/log(9)) +(1/log(10))
#         = 1 + 1/1 + 1/1.58 +1/2 + 1/2.32 + 1/2.58 + 1/2.8 + 1/3 + 1/3.17+ 1/3.32
#         = 1 + 1 + 0.63 + 0.5 + 0.43 + 0.39 + 0.36 + 0.33 + 0.31 + 0.3
#         =5.25
#
# IDCG can be calculated by re-ordering the retreived results by making all relevant results at top in decreasing order of their scores
#
#     IDCG = 1+ (1/log(2)) + (1/log(3)) + (1/log(4)) + (1/log(5)) + (1/log(6)) + (1/log(7)) + (1/log(8)) + (1/log(9)) +(1/log(10))
#         = 1 + 1/1 + 1/1.58 +1/2 + 1/2.32 + 1/2.58 + 1/2.8 + 1/3 + 1/3.17+ 1/3.32
#         = 1 + 1 + 0.63 + 0.5 + 0.43 + 0.39 +0.36 + 0.33 + 0.31 + 0.3
#         =5.25
#
# Normalized DCG(nDCG) can be calculated by using DCG and IDCG as shown below
#
#     nDCG = DCG/IDCG
#          =5.25/5.25
#          =1

# %% [markdown]
# Use case 3 : "COVID-19" on index "ms4976_info624_201904_newsproject3"

# %%
es.search(index = 'ms4976_info624_201904_newsproject3', body=
{"from":0, "size":10,
 "query": 
 {
   "bool":
   {
     "must":
     [{
        "multi_match": 
        {
          "query": "COVID-19",
          "fields": ["title","description"]
        }
     }],
     "should":
     {
       "rank_feature":
       {
         "field": "timestamp",
         "sigmoid":{"pivot": 5,"exponent":0.6}
       }
     } 
   }
  }
})

# %% [markdown]
# The information needs for this query ("COVID-19") is to find all relevant news articles from the "ms4976_info624_201904_newsproject3" index which are related to covid -19 virus. We can see from the query results that all the Top 10 retrieved results are relevant to our query information needs.
#
# Below are relevant and non-relevant document based on the query information needs
#
#     relevant = Doc1, Doc 2, Doc 3, Doc 4, Doc 5, Doc 6, Doc 7, Doc 8, Doc 9, Doc 10
#     non-relevant = Null
#
# For this query, we are getting no False Positive as all the retreived results are relevant to the information needs.

# %% [markdown]
# Precision is defined as percentage of retrieved docs that are relevant
#
#     Precision = True positive(TP)/True positive(TP) + False Positive(FP)
#               = 10/(10+0)
#               =10/10
#               =1
#
# DCG appears to have high value if the top retrieved documents are relevant
#
# Discounted cumulative gain can be given by below formula
#
#     DCG = rel1+ (rel2/log(2)) + (rel3/log(3)) + (rel4/log(4)) + (rel5/log(5)) + (rel6/log(6)) + (rel7/log(7)) + (rel8/log(8))   (rel9/log(9)) +(rel10/log(10))
#
# Here relevance value for any document will be 1 if the retrieved document is relevant to the query needs and 0 if the retrieved document is not relevant to the query needs
#
#     DCG = 1+ (1/log(2)) + (1/log(3)) + (1/log(4)) + (1/log(5)) + (1/log(6)) + (1/log(7)) + (1/log(8)) + (1/log(9)) +(1/log(10))
#         = 1 + 1/1 + 1/1.58 +1/2 + 1/2.32 + 1/2.58 + 1/2.8 + 1/3 + 1/3.17+ 1/3.32
#         = 1 + 1 + 0.63 + 0.5 + 0.43 + 0.39 + 0.36 + 0.33 + 0.31 + 0.3
#         =5.25
#
# IDCG can be calculated by re-ordering the retreived results by making all relevant results at top in decreasing order of their scores
#
#     IDCG = 1+ (1/log(2)) + (1/log(3)) + (1/log(4)) + (1/log(5)) + (1/log(6)) + (1/log(7)) + (1/log(8)) + (1/log(9)) +(1/log(10))
#         = 1 + 1/1 + 1/1.58 +1/2 + 1/2.32 + 1/2.58 + 1/2.8 + 1/3 + 1/3.17+ 1/3.32
#         = 1 + 1 + 0.63 + 0.5 + 0.43 + 0.39 +0.36 + 0.33 + 0.31 + 0.3
#         =5.25
#
# Normalized DCG(nDCG) can be calculated by using DCG and IDCG as shown below
#
#     nDCG = DCG/IDCG
#          =5.25/5.25
#          =1

# %% [markdown]
# Use case 4 : "Annie Karni articles on Trump" on index "ms4976_info624_201904_newsproject3"

# %%
es.search(index = 'ms4976_info624_201904_newsproject3', body=
{"from":0, "size":10,
 "query": 
 {
   "bool":
   {
     "must":
     [{
        "multi_match": 
        {
          "query": "Annie Karni articles on Donald Trump",
          "fields": ["author^5","title","description"]
        }
     }],
     "should":
     {
       "rank_feature":
       {
         "field": "timestamp",
         "sigmoid":{"pivot": 5,"exponent":0.6}
       }
     } 
   }
  }
})

# %% [markdown]
# The information needs for this query ("Annie Karni articles on Donald Trump") is to find all relevant news articles from the "ms4976_info624_201904_newsproject3" index which are Published by Annie Karni Author on any Donald Trump topics. We can see from  the Top 10 retrieved results Doc 1,Doc 2,Doc 3,Doc 4 are not relevant to our query information needs.
#
# Based on the above query information needs we can categorized these results into relevant and non-relevant document
#
#     relevant = Doc 5,Doc 6, Doc 7,Doc 8,Doc 9,Doc 10
#     non-relevant = Doc 1,Doc 2,Doc 3,Doc 4
#
# For this query, we are getting four False Positive document among top 10 retreived results and remaining all are relevant to the information needs.

# %% [markdown]
# Precision is defined as percentage of retrieved docs that are relevant
#
#     Precision = True positive(TP)/True positive(TP) + False Positive(FP)
#               = 6/(6+4)
#               =6/10
#               =0.6
#
# DCG appears to have high value if the top retrieved documents are relevant
#
# Discounted cumulative gain can be given by below formula:
#
#     DCG = rel1+ (rel2/log(2)) + (rel3/log(3)) + (rel4/log(4)) + (rel5/log(5)) + (rel6/log(6)) + (rel7/log(7)) + (rel8/log(8))   (rel9/log(9)) +(rel10/log(10))
#
# Here relevance value for any document will be 1 if the retrieved document is relevant to the query needs and 0 if the retrieved document is not relevant to the query needs
#
#     DCG =  0+ (0/log(2)) + (0/log(3)) + (0/log(4)) + (1/log(5)) + (1/log(6)) + (1/log(7)) + (1/log(8)) + (1/log(9)) +(1/log(10))
#         =  0 + 0 + 0 + 0 + 0.43 + 0.39 + 0.36 + 0.33 + 0.31 + 0.3
#         = 2.12
#
# IDCG can be calculated by re-ordering the retreived results by making all relevant results at top in decreasing order of their scores
#
#     IDCG = 1+ (1/log(2)) + (1/log(3)) + (1/log(4)) + (1/log(5)) + (1/log(6)) + (0/log(7)) + (0/log(8)) + (0/log(9)) +(0/log(10))
#         = 1 + 1/1 + 1/1.58 +1/2 + 1/2.32 + 1/2.58 + 0/2.8 + 0/3 + 0/3.17+ 0/3.32
#         = 1 + 1 + 0.63 + 0.5 + 0.43 + 0.39 + 0 + 0 + 0 + 0
#         =3.95
#
# Normalized DCG(nDCG) can be calculated by using DCG and IDCG as shown below
#
#     nDCG = DCG/IDCG
#          =2.12/3.95
#          =0.54

# %% [markdown]
# **Evaluation on  "ms4976_info624_201904_newsproject4" index which has different settings configuration**

# %% [markdown]
# Use case 1 : "US Elections" on index "ms4976_info624_201904_newsproject4"

# %%
es.search(index = 'ms4976_info624_201904_newsproject4', body=
{"from":0, "size":10,
 "query": 
 {
   "bool":
   {
     "must":
     [{
        "multi_match": 
        {
          "query": "crimes in US",
          "fields": ["title^2","description"]
        }
     }],
     "should":
     {
       "rank_feature":
       {
         "field": "timestamp",
         "sigmoid":{"pivot": 5,"exponent":0.6}
       }
     } 
   }
  }
})

# %% [markdown]
# The information needs for this query ("crimes in US") is to find all relevant news articles from the "ms4976_info624_201904_newsproject4" index which have any details regarding crimes in united states.We can see from  the Top 10 retrieved results Doc 1,Doc 5,Doc 8 are not relevant to our query information needs.
#
# Below are relevant and non-relevant document based on the query information needs
#
#     relevant = Doc 2,Doc 3,Doc 4,Doc 6, Doc 7,Doc 9,Doc 10
#     non-relevant = Doc 1,Doc 5,Doc 8

# %% [markdown]
# Precision is defined as percentage of retrieved docs that are relevant
#
#     Precision = True positive(TP)/True positive(TP) + False Positive(FP)
#               = 7/(7+3)
#               =7/10
#               =0.7
#
# DCG appears to have high value if the top retrieved documents are relevant
#
# Discounted cumulative gain can be given by below formula:
#
#     DCG = rel1+ (rel2/log(2)) + (rel3/log(3)) + (rel4/log(4)) + (rel5/log(5)) + (rel6/log(6)) + (rel7/log(7)) + (rel8/log(8))   (rel9/log(9)) +(rel10/log(10))
#
# Here relevance value for any document will be 1 if the retrieved document is relevant to the query needs and 0 if the retrieved document is not relevant to the query needs
#
#     DCG = 0+ (1/log(2)) + (1/log(3)) + (1/log(4)) + (0/log(5)) + (1/log(6)) + (1/log(7)) + (0/log(8)) + (1/log(9)) +(1/log(10))
#         = 0 + 1/1 + 1/1.58 +1/2 + 0/2.32 + 1/2.58 + 1/2.8 + 0/3 + 1/3.17+ 1/3.32
#         = 1 + 0.63 + 0.5 + 0.39 +0.36 + 0.31 + 0.3
#         =3.49
#
# IDCG can be calculated by re-ordering the retreived results by making all relevant results at top in decreasing order of their scores
#
#     IDCG = 1+ (1/log(2)) + (1/log(3)) + (1/log(4)) + (1/log(5)) + (1/log(6)) + (1/log(7)) + (0/log(8)) + (0/log(9)) +(0/log(10))
#          = 1 + 1/1 + 1/1.58 +1/2 + 1/2.32 + 1/2.58 + 1/2.8 + 0/3 + 0/3.17+ 0/3.32
#         = 1 + 1 + 0.63 + 0.5 +0.43 + 0.39 +0.36
#         =4.31
#
# Normalized DCG(nDCG) can be calculated by using DCG and IDCG as shown below
#
#     nDCG = DCG/IDCG
#          =3.49/4.31
#          =0.8

# %% [markdown]
# Use case 2 : "articles by BBC news" on index "ms4976_info624_201904_newsproject4"

# %%
es.search(index = 'ms4976_info624_201904_newsproject4', body=
{"from":0, "size":10,
 "query": 
 {
   "bool":
   {
     "must":
     [{
        "multi_match": 
        {
          "query": "articles by BBC news",
          "fields": ["source^3","title","description"]
        }
     }],
     "should":
     {
       "rank_feature":
       {
         "field": "timestamp",
         "sigmoid":{"pivot": 5,"exponent":0.6}
       }
     } 
   }
  }
})

# %% [markdown]
# The information needs for this query ("articles by BBC news") is to find all relevant news articles from the "ms4976_info624_201904_newsproject4" index which are published by BBC news source. We can see from the query results that all the Top 10 retrieved results are relevant to our query information needs.
#
# Below are relevant and non-relevant document based on the query information needs
#
#     relevant = Doc1, Doc 2, Doc 3, Doc 4, Doc 5, Doc 6, Doc 7, Doc 8, Doc 9, Doc 10
#     non-relevant = Null
#
# For this query, we are getting no False Positive as all the retreived results are relevant to the information needs

# %% [markdown]
# Precision is defined as percentage of retrieved docs that are relevant
#
#     Precision = True positive(TP)/True positive(TP) + False Positive(FP)
#               = 10/(10+0)
#               =10/10
#               =1
#
# DCG appears to have high value if the top retrieved documents are relevant
#
# Discounted cumulative gain can be given by below formula:
#
#     DCG = rel1+ (rel2/log(2)) + (rel3/log(3)) + (rel4/log(4)) + (rel5/log(5)) + (rel6/log(6)) + (rel7/log(7)) + (rel8/log(8))   (rel9/log(9)) +(rel10/log(10))
#
# Here relevance value for any document will be 1 if the retrieved document is relevant to the query needs and 0 if the retrieved document is not relevant to the query needs
#
#     DCG = 1+ (1/log(2)) + (1/log(3)) + (1/log(4)) + (1/log(5)) + (1/log(6)) + (1/log(7)) + (1/log(8)) + (1/log(9)) +(1/log(10))
#         = 1 + 1/1 + 1/1.58 +1/2 + 1/2.32 + 1/2.58 + 1/2.8 + 1/3 + 1/3.17+ 1/3.32
#         = 1 + 1 + 0.63 + 0.5 + 0.43 + 0.39 + 0.36 + 0.33 + 0.31 + 0.3
#         =5.25
#
# IDCG can be calculated by re-ordering the retreived results by making all relevant results at top in decreasing order of their scores
#
#     IDCG = 1+ (1/log(2)) + (1/log(3)) + (1/log(4)) + (1/log(5)) + (1/log(6)) + (1/log(7)) + (1/log(8)) + (1/log(9)) +(1/log(10))
#          = 1 + 1/1 + 1/1.58 +1/2 + 1/2.32 + 1/2.58 + 1/2.8 + 1/3 + 1/3.17+ 1/3.32
#          = 1 + 1 + 0.63 + 0.5 + 0.43 + 0.39 +0.36 + 0.33 + 0.31 + 0.3
#          =5.25
#
# Normalized DCG(nDCG) can be calculated by using DCG and IDCG as shown below
#
#     nDCG = DCG/IDCG
#          =5.25/5.25
#          =1

# %% [markdown]
# Use case 3 : "COVID-19" on index "ms4976_info624_201904_newsproject4"

# %%
es.search(index = 'ms4976_info624_201904_newsproject4', body=
{"from":0, "size":10,
 "query": 
 {
   "bool":
   {
     "must":
     [{
        "multi_match": 
        {
          "query": "COVID-19",
          "fields": ["title","description"]
        }
     }],
     "should":
     {
       "rank_feature":
       {
         "field": "timestamp",
         "sigmoid":{"pivot": 5,"exponent":0.6}
       }
     } 
   }
  }
})

# %% [markdown]
# The information needs for this query ("COVID-19") is to find all relevant news articles from the "ms4976_info624_201904_newsproject4" index which are related to covid -19 virus. We can see from the query results that all the Top 10 retrieved results are relevant to our query information needs.
#
# Below are relevant and non-relevant document based on the query information needs
#
#     relevant = Doc1, Doc 2, Doc 3, Doc 4, Doc 5, Doc 6, Doc 7, Doc 8, Doc 9, Doc 10
#     non-relevant = Null
#
# For this query, we are getting no False Positive as all the retreived results are relevant to the information needs.

# %% [markdown]
# Precision is defined as percentage of retrieved docs that are relevant
#
#     Precision = True positive(TP)/True positive(TP) + False Positive(FP)
#               = 10/(10+0)
#               =10/10
#               =1
#
# DCG appears to have high value if the top retrieved documents are relevant
#
# Discounted cumulative gain can be given by below formula:
#
#     DCG = rel1+ (rel2/log(2)) + (rel3/log(3)) + (rel4/log(4)) + (rel5/log(5)) + (rel6/log(6)) + (rel7/log(7)) + (rel8/log(8))   (rel9/log(9)) +(rel10/log(10))
#
# Here relevance value for any document will be 1 if the retrieved document is relevant to the query needs and 0 if the retrieved document is not relevant to the query needs
#
#     DCG = 1+ (1/log(2)) + (1/log(3)) + (1/log(4)) + (1/log(5)) + (1/log(6)) + (1/log(7)) + (1/log(8)) + (1/log(9)) +(1/log(10))
#         = 1 + 1/1 + 1/1.58 +1/2 + 1/2.32 + 1/2.58 + 1/2.8 + 1/3 + 1/3.17+ 1/3.32
#         = 1 + 1 + 0.63 + 0.5 + 0.43 + 0.39 + 0.36 + 0.33 + 0.31 + 0.3
#         =5.25
#
# IDCG can be calculated by re-ordering the retreived results by making all relevant results at top in decreasing order of their scores
#
#     IDCG = 1+ (1/log(2)) + (1/log(3)) + (1/log(4)) + (1/log(5)) + (1/log(6)) + (1/log(7)) + (1/log(8)) + (1/log(9)) +(1/log(10))
#         = 1 + 1/1 + 1/1.58 +1/2 + 1/2.32 + 1/2.58 + 1/2.8 + 1/3 + 1/3.17+ 1/3.32
#         = 1 + 1 + 0.63 + 0.5 + 0.43 + 0.39 +0.36 + 0.33 + 0.31 + 0.3
#         =5.25
#
# Normalized DCG(nDCG) can be calculated by using DCG and IDCG as shown below
#
#     nDCG = DCG/IDCG
#          =5.25/5.25
#          =1

# %% [markdown]
# #### Use case 4 : "Annie Karni articles on Trump" on index "ms4976_info624_201904_newsproject4"

# %%
es.search(index = 'ms4976_info624_201904_newsproject4', body=
{"from":0, "size":10,
 "query": 
 {
   "bool":
   {
     "must":
     [{
        "multi_match": 
        {
          "query": "Annie Karni articles on Donald Trump",
          "fields": ["author^5","title","description"]
        }
     }],
     "should":
     {
       "rank_feature":
       {
         "field": "timestamp",
         "sigmoid":{"pivot": 5,"exponent":0.6}
       }
     } 
   }
  }
})

# %% [markdown]
# The information needs for this query "Annie Karni articles on Donald Trump" is to find all relevant news articles from the "ms4976_info624_201904_newsproject4" index which are Published by Annie Karni Author on any Donald Trump topics.We can see from the query results that all the Top 10 retrieved results are relevant to our query information needs.
#
# Based on the above query information needs we can categorized these results into relevant and non-relevant document
#
#     relevant = Doc 1,Doc 2,Doc 3,Doc 4,Doc 5,Doc 6, Doc 7,Doc 8,Doc 9,Doc 10
#     non-relevant = Null
#
# For this query, we are getting Zero False Positive document's among top 10 retreived results all are relevant to the information needs.

# %% [markdown]
# Precision is defined as percentage of retrieved docs that are relevant
#
#     Precision = True positive(TP)/True positive(TP) + False Positive(FP)
#               = 10/(10+0)
#               =10/10
#               =1
#
# DCG appears to have high value if the top retrieved documents are relevant
#
# Discounted cumulative gain can be given by below formula
#
#     DCG = rel1+ (rel2/log(2)) + (rel3/log(3)) + (rel4/log(4)) + (rel5/log(5)) + (rel6/log(6)) + (rel7/log(7)) + (rel8/log(8))   (rel9/log(9)) +(rel10/log(10))
#
# Here relevance value for any document will be 1 if the retrieved document is relevant to the query needs and 0 if the retrieved document is not relevant to the query needs
#
#     DCG = 1+ (1/log(2)) + (1/log(3)) + (1/log(4)) + (1/log(5)) + (1/log(6)) + (1/log(7)) + (1/log(8)) + (1/log(9)) +(1/log(10))
#         = 1 + 1/1 + 1/1.58 +1/2 + 1/2.32 + 1/2.58 + 1/2.8 + 1/3 + 1/3.17+ 1/3.32
#         = 1 + 1 + 0.63 + 0.5 + 0.43 + 0.39 + 0.36 + 0.33 + 0.31 + 0.3
#         =5.25
#
# IDCG can be calculated by re-ordering the retreived results by making all relevant results at top in decreasing order of their scores
#
#     IDCG = 1+ (1/log(2)) + (1/log(3)) + (1/log(4)) + (1/log(5)) + (1/log(6)) + (1/log(7)) + (1/log(8)) + (1/log(9)) +(1/log(10))
#         = 1 + 1/1 + 1/1.58 +1/2 + 1/2.32 + 1/2.58 + 1/2.8 + 1/3 + 1/3.17+ 1/3.32
#         = 1 + 1 + 0.63 + 0.5 + 0.43 + 0.39 +0.36 + 0.33 + 0.31 + 0.3
#         =5.25
#
# Normalized DCG(nDCG) can be calculated by using DCG and IDCG as shown below:
#
#     nDCG = DCG/IDCG
#          =5.25/5.25
#          =1

# %% [markdown]
# **Comparision of all Indices**

# %% [markdown]
# |Index |usecase 1 precision|usecase 1 nDCG|usecase 2 precision|usecase 2 nDCG|usecase 3 precision|usecase 3 nDCG|usecase 4 precision|usecase 4 nDCG|Average precision|
# |------|---------|---------|---------|---------|---|------|---------|---------|---------|
# |ms4976_info624_201904_newsproject1|0.7|0.8|1|1|1|1|0.9|0.85|0.9|
# |ms4976_info624_201904_newsproject2|0.7|0.8|1|1|1|1|0.7|0.61|0.85|
# |ms4976_info624_201904_newsproject3|0.7|0.8|1|1|1|1|0.6|0.54|0.83|
# |ms4976_info624_201904_newsproject4|0.7|0.8|1|1|1|1|1|1|0.93|

# %% [markdown]
# In Evaluating our index, we are much focused on precision and nDCG metrics rather than recall metric as this is not important in our domain objective. We can't judge our search engine precision only by taking consideration of one query results so we have considered different use cases and we are taking average precision and nDCG values to evaluate our index performance.
#
# For all Indices, We obtained almost same precision results for most of the queries/use cases as our data collection is very small when compared to real time situations due to this our results has no significant difference and by considering the nDCG metric evaluations the index "ms4976_info624_201904_newsproject4" is giving better results compared to other indices and as we  more interested on the top relevant results than lower order relevant results we have choosen this index as best in our case.
#
# Note: All the indices setting and mappings details are provided in Custom Similarities Comparision jupyter notebook.
